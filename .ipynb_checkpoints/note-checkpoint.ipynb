# %% [markdown]
# ### Lecture 2 Pandas I

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
s = pd.Series(["a", "b", "c"]) #创建无索引的Series对象
s
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s.values
# Out:
# array(['a', 'b', 'c'], dtype=object)

# %%
s = pd.Series(["a", "b", "c"], index = [10, 100, 1000]) #创建有索引的Series对象
s
# Out:
# 10      a
# 100     b
# 1000    c
# dtype: object

# %%
s.index
# Out:
# Index([10, 100, 1000], dtype='int64')

# %%
s.values
# Out:
# array(['a', 'b', 'c'], dtype=object)

# %%
s.index = [1, 2, 3] #改变索引的值
s
# Out:
# 1    a
# 2    b
# 3    c
# dtype: object

# %%
s = pd.Series([4, 0, -2, 6], index = ["a", "b", "c", "d"])
s[["a", "c"]] #索引给定行
# Out:
# a    4
# c   -2
# dtype: int64

# %%
s > 0
# Out:
# a     True
# b    False
# c    False
# d     True
# dtype: bool

# %%
s[s > 0]
# Out:
# a    4
# d    6
# dtype: int64

# %%
s[s % 2 == 0]
# Out:
# a    4
# b    0
# c   -2
# d    6
# dtype: int64

# %%
elections = pd.read_csv("lecture/lec02/data/elections.csv") #读取csv文件为DataFrame
elections
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# ...

# %%
elections = pd.read_csv("lecture/lec02/data/elections.csv", index_col = "Year")
elections
# Out:
#               Candidate                  Party  Popular vote Result          %
# Year
# 1824     Andrew Jackson  Democratic-Republican        151271   loss  57.210122
# 1824  John Quincy Adams  Democratic-Republican        113142    win  42.789878
# 1828     Andrew Jackson             Democratic        642806    win  56.203927
# 1828  John Quincy Adams    National Republican        500897   loss  43.796073
# 1832     Andrew Jackson             Democratic        702735    win  54.574789
# ...                 ...                    ...           ...    ...        ...
# 2016         Jill Stein                  Green       1457226   loss   1.073699
# 2020       Joseph Biden             Democratic      81268924    win  51.311515
# 2020       Donald Trump             Republican      74216154   loss  46.858542
# 2020       Jo Jorgensen            Libertarian       1865724   loss   1.177979
# 2020     Howard Hawkins                  Green        405035   loss   0.255731
#
# ...

# %%
elections = elections.reset_index() #重置索引
elections
# Out:
#      Year          Candidate                  Party  Popular vote Result  \
# 0    1824     Andrew Jackson  Democratic-Republican        151271   loss
# 1    1824  John Quincy Adams  Democratic-Republican        113142    win
# 2    1828     Andrew Jackson             Democratic        642806    win
# 3    1828  John Quincy Adams    National Republican        500897   loss
# 4    1832     Andrew Jackson             Democratic        702735    win
# ..    ...                ...                    ...           ...    ...
# 177  2016         Jill Stein                  Green       1457226   loss
# 178  2020       Joseph Biden             Democratic      81268924    win
# 179  2020       Donald Trump             Republican      74216154   loss
# 180  2020       Jo Jorgensen            Libertarian       1865724   loss
# 181  2020     Howard Hawkins                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# ...

# %%
elections = elections.set_index("Candidate") #设置索引
elections
# Out:
#                    Year                  Party  Popular vote Result          %
# Candidate
# Andrew Jackson     1824  Democratic-Republican        151271   loss  57.210122
# John Quincy Adams  1824  Democratic-Republican        113142    win  42.789878
# Andrew Jackson     1828             Democratic        642806    win  56.203927
# John Quincy Adams  1828    National Republican        500897   loss  43.796073
# Andrew Jackson     1832             Democratic        702735    win  54.574789
# ...                 ...                    ...           ...    ...        ...
# Jill Stein         2016                  Green       1457226   loss   1.073699
# Joseph Biden       2020             Democratic      81268924    win  51.311515
# Donald Trump       2020             Republican      74216154   loss  46.858542
# Jo Jorgensen       2020            Libertarian       1865724   loss   1.177979
# Howard Hawkins     2020                  Green        405035   loss   0.255731
#
# ...

# %%
numbers = pd.DataFrame([[1, "one"], [2, "two"]],
                       columns = ["Number", "Eng"])
numbers
# Out:
#    Number  Eng
# 0       1  one
# 1       2  two

# %%
Fruits = pd.DataFrame({"Fruit" : ["apple", "pear", "banana"],
                       "Price" : [5.99, 6.25, 7]}) #用字典创建DataFrame
Fruits
# Out:
#     Fruit  Price
# 0   apple   5.99
# 1    pear   6.25
# 2  banana   7.00

# %%
elections.columns
# Out:
# Index(['Year', 'Party', 'Popular vote', 'Result', '%'], dtype='object')

# %%
elections.shape
# Out:
# (182, 5)

# %%
elections = elections.reset_index()
elections
# Out:
#              Candidate  Year                  Party  Popular vote Result  \
# 0       Andrew Jackson  1824  Democratic-Republican        151271   loss
# 1    John Quincy Adams  1824  Democratic-Republican        113142    win
# 2       Andrew Jackson  1828             Democratic        642806    win
# 3    John Quincy Adams  1828    National Republican        500897   loss
# 4       Andrew Jackson  1832             Democratic        702735    win
# ..                 ...   ...                    ...           ...    ...
# 177         Jill Stein  2016                  Green       1457226   loss
# 178       Joseph Biden  2020             Democratic      81268924    win
# 179       Donald Trump  2020             Republican      74216154   loss
# 180       Jo Jorgensen  2020            Libertarian       1865724   loss
# 181     Howard Hawkins  2020                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# ...

# %%
elections.loc[[3, 5, 7], ["Year", "Party"]] #df.loc[row_lables, column_labels]
# Out:
#    Year                Party
# 3  1828  National Republican
# 5  1832  National Republican
# 7  1836                 Whig

# %%
elections.iloc[[3, 5, 7], [1, 2]] #df.iloc[row_integers, column_integers]
# Out:
#    Year                Party
# 3  1828  National Republican
# 5  1832  National Republican
# 7  1836                 Whig

# %% [markdown]
# ### Lecture 3 Pandas II

# %%
#用逻辑运算选择对应的行
logical_operator = (elections["Result"] == "win")

# %%
elections[logical_operator]
# Out:
#                   Candidate  Year                  Party  Popular vote Result  \
# 1         John Quincy Adams  1824  Democratic-Republican        113142    win
# 2            Andrew Jackson  1828             Democratic        642806    win
# 4            Andrew Jackson  1832             Democratic        702735    win
# 8          Martin Van Buren  1836             Democratic        763291    win
# 11   William Henry Harrison  1840                   Whig       1275583    win
# 13               James Polk  1844             Democratic       1339570    win
# 16           Zachary Taylor  1848                   Whig       1360235    win
# 17          Franklin Pierce  1852             Democratic       1605943    win
# 20           James Buchanan  1856             Democratic       1835140    win
# 23          Abraham Lincoln  1860             Republican       1855993    win
# 27          Abraham Lincoln  1864         National Union       2211317    win
# ...

# %%
elections.loc[logical_operator, "Candidate"]
# Out:
# 1           John Quincy Adams
# 2              Andrew Jackson
# 4              Andrew Jackson
# 8            Martin Van Buren
# 11     William Henry Harrison
# 13                 James Polk
# 16             Zachary Taylor
# 17            Franklin Pierce
# 20             James Buchanan
# 23            Abraham Lincoln
# 27            Abraham Lincoln
# 30              Ulysses Grant
# 32              Ulysses Grant
# 33           Rutherford Hayes
# 36             James Garfield
# 39           Grover Cleveland
# 43          Benjamin Harrison
# 47           Grover Cleveland
# 53           William McKinley
# 56           William McKinley
# 60         Theodore Roosevelt
# 65               William Taft
# 70             Woodrow Wilson
# 74             Woodrow Wilson
# 79             Warren Harding
# 80            Calvin Coolidge
# 84             Herbert Hoover
# 86         Franklin Roosevelt
# 91         Franklin Roosevelt
# 94         Franklin Roosevelt
# 97         Franklin Roosevelt
# ...

# %%
#用 & 表示 and， | 表示 or， ~ 表示 nagation
elections[(elections["Result"] == "win") & (elections["Year"] < 1900)]
# Out:
#                  Candidate  Year                  Party  Popular vote Result  \
# 1        John Quincy Adams  1824  Democratic-Republican        113142    win
# 2           Andrew Jackson  1828             Democratic        642806    win
# 4           Andrew Jackson  1832             Democratic        702735    win
# 8         Martin Van Buren  1836             Democratic        763291    win
# 11  William Henry Harrison  1840                   Whig       1275583    win
# 13              James Polk  1844             Democratic       1339570    win
# 16          Zachary Taylor  1848                   Whig       1360235    win
# 17         Franklin Pierce  1852             Democratic       1605943    win
# 20          James Buchanan  1856             Democratic       1835140    win
# 23         Abraham Lincoln  1860             Republican       1855993    win
# 27         Abraham Lincoln  1864         National Union       2211317    win
# ...

# %%
elections[elections["Year"].isin([1900, 1904, 1980])]
# Out:
#                   Candidate  Year        Party  Popular vote Result          %
# 54          John G. Woolley  1900  Prohibition        210864   loss   1.526821
# 55   William Jennings Bryan  1900   Democratic       6370932   loss  46.130540
# 56         William McKinley  1900   Republican       7228864    win  52.342640
# 57          Alton B. Parker  1904   Democratic       5083880   loss  37.685116
# 58           Eugene V. Debs  1904    Socialist        402810   loss   2.985897
# 59         Silas C. Swallow  1904  Prohibition        259102   loss   1.920637
# 60       Theodore Roosevelt  1904   Republican       7630557    win  56.562787
# 61         Thomas E. Watson  1904     Populist        114070   loss   0.845563
# 127          Barry Commoner  1980     Citizens        233052   loss   0.270182
# 128                Ed Clark  1980  Libertarian        921128   loss   1.067883
# 129            Jimmy Carter  1980   Democratic      35480115   loss  41.132848
# ...

# %%
elections[elections["Candidate"].str.startswith("A")]
# Out:
#             Candidate  Year                  Party  Popular vote Result  \
# 0      Andrew Jackson  1824  Democratic-Republican        151271   loss
# 2      Andrew Jackson  1828             Democratic        642806    win
# 4      Andrew Jackson  1832             Democratic        702735    win
# 23    Abraham Lincoln  1860             Republican       1855993    win
# 27    Abraham Lincoln  1864         National Union       2211317    win
# 42     Alson Streeter  1888            Union Labor        146602   loss
# 57    Alton B. Parker  1904             Democratic       5083880   loss
# 71    Allan L. Benson  1916              Socialist        590524   loss
# 75   Aaron S. Watkins  1920            Prohibition        188787   loss
# 83           Al Smith  1928             Democratic      15015464   loss
# 90         Alf Landon  1936             Republican      16679543   loss
# 105   Adlai Stevenson  1952             Democratic      27375090   loss
# ...

# %%
#通过[]可以直接添加一列 
name_length = elections["Candidate"].str.len()
elections["name_length"] = name_length
elections
# Out:
#              Candidate  Year                  Party  Popular vote Result  \
# 0       Andrew Jackson  1824  Democratic-Republican        151271   loss
# 1    John Quincy Adams  1824  Democratic-Republican        113142    win
# 2       Andrew Jackson  1828             Democratic        642806    win
# 3    John Quincy Adams  1828    National Republican        500897   loss
# 4       Andrew Jackson  1832             Democratic        702735    win
# ..                 ...   ...                    ...           ...    ...
# 177         Jill Stein  2016                  Green       1457226   loss
# 178       Joseph Biden  2020             Democratic      81268924    win
# 179       Donald Trump  2020             Republican      74216154   loss
# 180       Jo Jorgensen  2020            Libertarian       1865724   loss
# 181     Howard Hawkins  2020                  Green        405035   loss
#
#              %  name_length
# 0    57.210122           14
# 1    42.789878           17
# ...

# %%
#rename 重命名
elections = elections.rename(columns={"name_length":"Length"})
elections
# Out:
#              Candidate  Year                  Party  Popular vote Result  \
# 0       Andrew Jackson  1824  Democratic-Republican        151271   loss
# 1    John Quincy Adams  1824  Democratic-Republican        113142    win
# 2       Andrew Jackson  1828             Democratic        642806    win
# 3    John Quincy Adams  1828    National Republican        500897   loss
# 4       Andrew Jackson  1832             Democratic        702735    win
# ..                 ...   ...                    ...           ...    ...
# 177         Jill Stein  2016                  Green       1457226   loss
# 178       Joseph Biden  2020             Democratic      81268924    win
# 179       Donald Trump  2020             Republican      74216154   loss
# 180       Jo Jorgensen  2020            Libertarian       1865724   loss
# 181     Howard Hawkins  2020                  Green        405035   loss
#
#              %  Length
# 0    57.210122      14
# 1    42.789878      17
# ...

# %%
#drop 删除 默认删除一行
elections.drop("Length", axis = "columns")
# Out:
#              Candidate  Year                  Party  Popular vote Result  \
# 0       Andrew Jackson  1824  Democratic-Republican        151271   loss
# 1    John Quincy Adams  1824  Democratic-Republican        113142    win
# 2       Andrew Jackson  1828             Democratic        642806    win
# 3    John Quincy Adams  1828    National Republican        500897   loss
# 4       Andrew Jackson  1832             Democratic        702735    win
# ..                 ...   ...                    ...           ...    ...
# 177         Jill Stein  2016                  Green       1457226   loss
# 178       Joseph Biden  2020             Democratic      81268924    win
# 179       Donald Trump  2020             Republican      74216154   loss
# 180       Jo Jorgensen  2020            Libertarian       1865724   loss
# 181     Howard Hawkins  2020                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# ...

# %%
elections.describe()
# Out:
#               Year  Popular vote           %      Length
# count   182.000000  1.820000e+02  182.000000  182.000000
# mean   1934.087912  1.235364e+07   27.470350   14.170330
# std      57.048908  1.907715e+07   22.968034    2.927975
# min    1824.000000  1.007150e+05    0.098088    7.000000
# 25%    1889.000000  3.876395e+05    1.219996   12.000000
# 50%    1936.000000  1.709375e+06   37.677893   14.000000
# 75%    1988.000000  1.897775e+07   48.354977   16.000000
# max    2020.000000  8.126892e+07   61.344703   22.000000

# %%
elections["Year"].describe()
# Out:
# count     182.000000
# mean     1934.087912
# std        57.048908
# min      1824.000000
# 25%      1889.000000
# 50%      1936.000000
# 75%      1988.000000
# max      2020.000000
# Name: Year, dtype: float64

# %%
elections["Candidate"].describe()
# Out:
# count               182
# unique              132
# top       Norman Thomas
# freq                  5
# Name: Candidate, dtype: object

# %%
elections.sample(5)  #抽样
# Out:
#            Candidate  Year        Party  Popular vote Result          %  \
# 19    Winfield Scott  1852         Whig       1386942   loss  44.056548
# 70    Woodrow Wilson  1912   Democratic       6296284    win  41.933422
# 40   James G. Blaine  1884   Republican       4856905   loss  48.312208
# 146     Harry Browne  1996  Libertarian        485759   loss   0.505198
# 54   John G. Woolley  1900  Prohibition        210864   loss   1.526821
#
#      Length
# 19       14
# 70       14
# 40       15
# 146      12
# 54       15

# %%
elections["Candidate"].value_counts()
# Out:
# Candidate
# Norman Thomas             5
# Ralph Nader               4
# Eugene V. Debs            4
# Franklin Roosevelt        4
# William Jennings Bryan    3
#                          ..
# Evan McMullin             1
# Hillary Clinton           1
# Joseph Biden              1
# Jo Jorgensen              1
# Howard Hawkins            1
# Name: count, Length: 132, dtype: int64

# %%
elections["Candidate"].unique()
# Out:
# array(['Andrew Jackson', 'John Quincy Adams', 'Henry Clay',
#        'William Wirt', 'Hugh Lawson White', 'Martin Van Buren',
#        'William Henry Harrison', 'James Polk', 'Lewis Cass',
#        'Zachary Taylor', 'Franklin Pierce', 'John P. Hale',
#        'Winfield Scott', 'James Buchanan', 'John C. Frémont',
#        'Millard Fillmore', 'Abraham Lincoln', 'John Bell',
#        'John C. Breckinridge', 'Stephen A. Douglas',
#        'George B. McClellan', 'Horatio Seymour', 'Ulysses Grant',
#        'Horace Greeley', 'Rutherford Hayes', 'Samuel J. Tilden',
#        'James B. Weaver', 'James Garfield', 'Winfield Scott Hancock',
#        'Benjamin Butler', 'Grover Cleveland', 'James G. Blaine',
#        'John St. John', 'Alson Streeter', 'Benjamin Harrison',
#        'Clinton B. Fisk', 'John Bidwell', 'John M. Palmer',
#        'Joshua Levering', 'William Jennings Bryan', 'William McKinley',
#        'John G. Woolley', 'Alton B. Parker', 'Eugene V. Debs',
# ...

# %%
elections["%"].sort_values() #排序 默认升序
# Out:
# 156     0.098088
# 141     0.101918
# 160     0.117542
# 148     0.118219
# 165     0.123442
#          ...
# 133    59.023326
# 79     60.574501
# 120    60.907806
# 91     60.978107
# 114    61.344703
# Name: %, Length: 182, dtype: float64

# %%
elections.sort_values(by="%", ascending=False)
# Out:
#               Candidate  Year         Party  Popular vote Result          %  \
# 114      Lyndon Johnson  1964    Democratic      43127041    win  61.344703
# 91   Franklin Roosevelt  1936    Democratic      27752648    win  60.978107
# 120       Richard Nixon  1972    Republican      47168710    win  60.907806
# 79       Warren Harding  1920    Republican      16144093    win  60.574501
# 133       Ronald Reagan  1984    Republican      54455472    win  59.023326
# ..                  ...   ...           ...           ...    ...        ...
# 165    Cynthia McKinney  2008         Green        161797   loss   0.123442
# 148        John Hagelin  1996   Natural Law        113670   loss   0.118219
# 160    Michael Peroutka  2004  Constitution        143630   loss   0.117542
# 141            Bo Gritz  1992      Populist        106152   loss   0.101918
# 156          David Cobb  2004         Green        119859   loss   0.098088
#
#      Length
# 114      14
# 91       18
# 120      13
# ...

# %% [markdown]
# ### Lecture 4 Pandas III

# %%
#自定义排序 key
elections.sort_values(by="Candidate", key=lambda x : x.str.len(), ascending=False).head()
# Out:
#                  Candidate  Year       Party  Popular vote Result          %  \
# 11  William Henry Harrison  1840        Whig       1275583    win  53.051213
# 9   William Henry Harrison  1836        Whig        550816   loss  37.721543
# 52  William Jennings Bryan  1896  Democratic       6509052   loss  46.871053
# 37  Winfield Scott Hancock  1880  Democratic       4444976   loss  48.278422
# 64  William Jennings Bryan  1908  Democratic       6408979   loss  43.414640
#
#     Length
# 11      22
# 9       22
# 52      22
# 37      22
# 64      22

# %%
#用map排序
def dr_ea_count(string):
    return string.count('dr') + string.count('ea')
elections["dr_ea_count"] = elections["Candidate"].map(dr_ea_count)
elections.sort_values(by="dr_ea_count", ascending=False)
# Out:
#            Candidate  Year                  Party  Popular vote Result  \
# 0     Andrew Jackson  1824  Democratic-Republican        151271   loss
# 2     Andrew Jackson  1828             Democratic        642806    win
# 4     Andrew Jackson  1832             Democratic        702735    win
# 35   James B. Weaver  1880              Greenback        308649   loss
# 48   James B. Weaver  1892               Populist       1041028   loss
# ..               ...   ...                    ...           ...    ...
# 177       Jill Stein  2016                  Green       1457226   loss
# 178     Joseph Biden  2020             Democratic      81268924    win
# 179     Donald Trump  2020             Republican      74216154   loss
# 180     Jo Jorgensen  2020            Libertarian       1865724   loss
# 181   Howard Hawkins  2020                  Green        405035   loss
#
#              %  Length  dr_ea_count
# 0    57.210122      14            1
# 2    56.203927      14            1
# ...

# %%
#dataframe.gruopby(column_name).agg(aggregation_function)
elections[["Year", "Popular vote"]].groupby("Year").agg(sum)
# Out:
# C:\Users\shuichi\AppData\Local\Temp\ipykernel_14644\524293030.py:2: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   elections[["Year", "Popular vote"]].groupby("Year").agg(sum)
#       Popular vote
# Year
# 1824        264413
# 1828       1143703
# 1832       1287655
# 1836       1460216
# 1840       2404437
# 1844       2639574
# 1848       2875196
# 1852       3148095
# 1856       4050538
# 1860       4675115
# 1864       4024124
# 1868       5722534
# 1872       6432200
# 1876       8322688
# 1880       9206962
# 1884      10053163
# 1888      11374542
# 1892      12041913
# 1896      13887147
# 1900      13810660
# 1904      13490419
# 1908      14762253
# 1912      15014954
# 1916      18487422
# 1920      26651632
# 1924      28941737
# 1928      36710065
# 1932      39570723
# ...

# %%
elections.groupby("Year").sum(numeric_only=True)
# Out:
#       Popular vote           %  Length  dr_ea_count
# Year
# 1824        264413  100.000000      31            1
# 1828       1143703  100.000000      31            1
# 1832       1287655  100.000000      36            1
# 1836       1460216  100.000000      55            0
# 1840       2404437  100.000000      38            0
# 1844       2639574  100.000000      20            0
# 1848       2875196  100.000000      40            0
# 1852       3148095  100.000000      41            0
# 1856       4050538  100.000000      45            0
# 1860       4675115  100.000000      62            0
# 1864       4024124  100.000000      34            0
# 1868       5722534  100.000000      28            0
# 1872       6432200  100.000000      27            0
# 1876       8322688  100.000000      32            0
# 1880       9206962  100.000000      51            1
# 1884      10053163  100.000000      59            0
# 1888      11374542  100.000000      62            0
# ...

# %%
elections.drop("dr_ea_count", axis="columns", inplace=True)
elections.drop("Length", axis="columns", inplace=True)
elections
# Out:
#              Candidate  Year                  Party  Popular vote Result  \
# 0       Andrew Jackson  1824  Democratic-Republican        151271   loss
# 1    John Quincy Adams  1824  Democratic-Republican        113142    win
# 2       Andrew Jackson  1828             Democratic        642806    win
# 3    John Quincy Adams  1828    National Republican        500897   loss
# 4       Andrew Jackson  1832             Democratic        702735    win
# ..                 ...   ...                    ...           ...    ...
# 177         Jill Stein  2016                  Green       1457226   loss
# 178       Joseph Biden  2020             Democratic      81268924    win
# 179       Donald Trump  2020             Republican      74216154   loss
# 180       Jo Jorgensen  2020            Libertarian       1865724   loss
# 181     Howard Hawkins  2020                  Green        405035   loss
#
#              %
# 0    57.210122
# 1    42.789878
# 2    56.203927
# 3    43.796073
# ...

# %%
elections.groupby("Year").filter(lambda sf : sf["%"].max() < 45)
# Out:
#                 Candidate  Year                 Party  Popular vote Result  \
# 23        Abraham Lincoln  1860            Republican       1855993    win
# 24              John Bell  1860  Constitutional Union        590901   loss
# 25   John C. Breckinridge  1860   Southern Democratic        848019   loss
# 26     Stephen A. Douglas  1860   Northern Democratic       1380202   loss
# 66         Eugene V. Debs  1912             Socialist        901551   loss
# 67       Eugene W. Chafin  1912           Prohibition        208156   loss
# 68     Theodore Roosevelt  1912           Progressive       4122721   loss
# 69           William Taft  1912            Republican       3486242   loss
# 70         Woodrow Wilson  1912            Democratic       6296284    win
# 115        George Wallace  1968  American Independent       9901118   loss
# 116       Hubert Humphrey  1968            Democratic      31271839   loss
# ...

# %%
elections.sort_values(by="%", ascending=False).groupby("Party").first()
# Out:
#                                     Candidate  Year  Popular vote Result  \
# Party
# American                     Millard Fillmore  1856        873053   loss
# American Independent           George Wallace  1968       9901118   loss
# Anti-Masonic                     William Wirt  1832        100715   loss
# Anti-Monopoly                 Benjamin Butler  1884        134294   loss
# Citizens                       Barry Commoner  1980        233052   loss
# Communist                   William Z. Foster  1932        103307   loss
# Constitution                    Chuck Baldwin  2008        199750   loss
# Constitutional Union                John Bell  1860        590901   loss
# Democratic                     Lyndon Johnson  1964      43127041    win
# Democratic-Republican          Andrew Jackson  1824        151271   loss
# Dixiecrat                      Strom Thurmond  1948       1175930   loss
# Farmer–Labor            Parley P. Christensen  1920        265398   loss
# ...

# %%
elections.sort_values(by="%").drop_duplicates(["Party"], keep="last")
# Out:
#                   Candidate  Year                  Party  Popular vote Result  \
# 148            John Hagelin  1996            Natural Law        113670   loss
# 164           Chuck Baldwin  2008           Constitution        199750   loss
# 110      T. Coleman Andrews  1956         States' Rights        107929   loss
# 147         Howard Phillips  1996              Taxpayers        184656   loss
# 136           Lenora Fulani  1988           New Alliance        217221   loss
# 89        William Z. Foster  1932              Communist        103307   loss
# 127          Barry Commoner  1980               Citizens        233052   loss
# 50           John M. Palmer  1896    National Democratic        134645   loss
# 78    Parley P. Christensen  1920           Farmer–Labor        265398   loss
# 42           Alson Streeter  1888            Union Labor        146602   loss
# 38          Benjamin Butler  1884          Anti-Monopoly        134294   loss
# ...

# %%
grouped_by_party = elections.groupby("Party")
grouped_by_party.groups
# Out:
# {'American': [22, 126], 'American Independent': [115, 119, 124], 'Anti-Masonic': [6], 'Anti-Monopoly': [38], 'Citizens': [127], 'Communist': [89], 'Constitution': [160, 164, 172], 'Constitutional Union': [24], 'Democratic': [2, 4, 8, 10, 13, 14, 17, 20, 28, 29, 34, 37, 39, 45, 47, 52, 55, 57, 64, 70, 74, 77, 81, 83, 86, 91, 94, 97, 100, 105, 108, 111, 114, 116, 118, 123, 129, 134, 137, 140, 144, 151, 158, 162, 168, 176, 178], 'Democratic-Republican': [0, 1], 'Dixiecrat': [103], 'Farmer–Labor': [78], 'Free Soil': [15, 18], 'Green': [149, 155, 156, 165, 170, 177, 181], 'Greenback': [35], 'Independent': [121, 130, 143, 161, 167, 174], 'Liberal Republican': [31], 'Libertarian': [125, 128, 132, 138, 139, 146, 153, 159, 163, 169, 175, 180], 'National Democratic': [50], 'National Republican': [3, 5], 'National Union': [27], 'Natural Law': [148], 'New Alliance': [136], 'Northern Democratic': [26], 'Populist': [48, 61, 141], 'Progressive': [68, 82, 101, 107], 'Prohibition': [41, 44, 49, 51, 5
# ...

# %%
grouped_by_party.get_group("Socialist")
# Out:
#            Candidate  Year      Party  Popular vote Result         %
# 58    Eugene V. Debs  1904  Socialist        402810   loss  2.985897
# 62    Eugene V. Debs  1908  Socialist        420852   loss  2.850866
# 66    Eugene V. Debs  1912  Socialist        901551   loss  6.004354
# 71   Allan L. Benson  1916  Socialist        590524   loss  3.194193
# 76    Eugene V. Debs  1920  Socialist        913693   loss  3.428282
# 85     Norman Thomas  1928  Socialist        267478   loss  0.728623
# 88     Norman Thomas  1932  Socialist        884885   loss  2.236211
# 92     Norman Thomas  1936  Socialist        187910   loss  0.412876
# 95     Norman Thomas  1940  Socialist        116599   loss  0.234237
# 102    Norman Thomas  1948  Socialist        139569   loss  0.286312

# %%
elections_pivot = elections.pivot_table(
    index = "Year",
    columns = "Result",
    values = ["%"],
    aggfunc = np.max,
)
elections_pivot.head(5)
# Out:
# C:\Users\shuichi\AppData\Local\Temp\ipykernel_14644\1091789219.py:1: FutureWarning: The provided callable <function max at 0x000001695EE560D0> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   elections_pivot = elections.pivot_table(
#                 %
# Result       loss        win
# Year
# 1824    57.210122  42.789878
# 1828    43.796073  56.203927
# 1832    37.603628  54.574789
# 1836    37.721543  52.272472
# 1840    46.948787  53.051213

# %% [markdown]
# ### Lecture 5 Data Wrangling and EDA (Part 1)
