# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
wb = pd.read_csv("../lecture/lec08/data/world_bank.csv")
wb
# Out:
#      Unnamed: 0   Continent   Country  \
# 0             0      Africa   Algeria
# 1             1      Africa    Angola
# 2             2      Africa     Benin
# 3             3      Africa  Botswana
# 4             5      Africa   Burundi
# ..          ...         ...       ...
# 161         188  S. America    Guyana
# 162         189  S. America  Paraguay
# 163         190  S. America      Peru
# 164         191  S. America  Suriname
# 165         192  S. America   Uruguay
#
#      Primary completion rate: Male: % of relevant age group: 2015  \
# 0                                                106.0
# 1                                                  NaN
# 2                                                 83.0
# 3                                                 98.0
# 4                                                 58.0
# ..                                                 ...
# 161                                               87.0
# ...

# %%
sns.histplot(data=wb, 
             x='Primary completion rate: Male: % of relevant age group: 2015', 
             kde=True,
             stat='density')
# Out:
# <Axes: xlabel='Primary completion rate: Male: % of relevant age group: 2015', ylabel='Density'>

# %%
sns.displot(data=wb, 
             x='Primary completion rate: Male: % of relevant age group: 2015', 
             kind='hist',
             stat='density')
